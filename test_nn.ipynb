# %%
import matplotlib.pyplot as plt
import numpy as np
import cPickle
from nn import *
# %matplotlib inline

# %%
with open("nn.pkl") as fin:
    network = cPickle.load(fin)

nn_x = np.linspace(0, 2 * np.pi, 1000).reshape((1, -1))
nn_y = network.predict(nn_x)

plt.title("Fitted curve of CPU NN")
plt.plot(nn_x.ravel(), nn_y.ravel())
plt.show()

# %%
nn_y = np.genfromtxt("output.txt", delimiter="\n")
nn_x = np.linspace(0, 2 * np.pi, 1000).reshape((1, -1))

plt.title("Fitted curve of GPU NN")
plt.plot(nn_x.ravel(), nn_y.ravel())
plt.show()
